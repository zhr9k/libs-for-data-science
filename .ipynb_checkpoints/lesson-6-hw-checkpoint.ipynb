# %% [markdown]
# ## Задание 1

# %% [markdown]
# ### предисловие
# я немного дополнительных графиков построил. решил сначала графически посмотреть, как будут выглядеть средние/сигмы при стандартизации данных, а потом посмотреть как будет с метриками (r2, квадраты и абсолютные разности) при просто скейлинге, а потом если убирать колонки, которые вносят мало веса

# %% [markdown]
# Импортируйте библиотеки pandas и numpy.
# Загрузите "Boston House Prices dataset" из встроенных наборов данных библиотеки sklearn.<br>

# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt
from sklearn import datasets
from sklearn import metrics
from sklearn import preprocessing
import seaborn as sns
# %config InlineBackend.figure_format = 'svg'

plt.rcParams['figure.figsize'] = 6, 4

# %matplotlib inline

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
boston = datasets.load_boston()

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
data = boston['data']
features = boston['feature_names']
target = boston['target']

# %% [markdown]
# Создайте датафреймы X и Y из этих данных.<br>

# %%
X = pd.DataFrame(data, columns=features)

# %%
X = reduce_mem_usage(X)
# Out:
# Memory usage of dataframe is 0.05 MB
# Memory usage after optimization is: 0.03 MB
# Decreased by 49.9%

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.199997  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.900002  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.099998  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.799999  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.200001  6.0622  3.0  222.0
#
#      PTRATIO           B  LSTAT
# 0  15.300000  396.899994   4.98
# 1  17.799999  396.899994   9.14
# 2  17.799999  392.829987   4.03
# 3  18.700001  394.630005   2.94
# 4  18.700001  396.899994   5.33

# %%
Y = pd.DataFrame(target, columns=['price'])
Y.head()
# Out:
#    price
# 0   24.0
# 1   21.6
# 2   34.7
# 3   33.4
# 4   36.2

# %% [markdown]
# Разбейте эти датафреймы н а тренировочные (X_train, y_train) и тестовые (X_test, y_test) с помощью функции train_test_split <br>так, чтобы размер тестовой выборки
# составлял 30% от всех данных, при этом аргумент random_state должен быть равен 42.<br>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
print(X_train.shape,'\n',X_test.shape)
# Out:
# (354, 13)
#  (152, 13)

# %% [markdown]
# Создайте модель линейной регрессии под названием lr с помощью класса LinearRegression из модуля sklearn.linear_model.<br>

# %%
lr = LinearRegression()

# %% [markdown]
# Обучите модель на тренировочных данных (используйте все признаки)

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# посмотрим коэффициенты $w_{i}$

# %%
print(lr.intercept_, '\n',lr.coef_ )
# Out:
# [31.63108404]
#  [[-1.33470103e-01  3.58089136e-02  4.95226452e-02  3.11983512e+00
#   -1.54170609e+01  4.05719923e+00 -1.08208352e-02 -1.38599824e+00
#    2.42727340e-01 -8.70223437e-03 -9.10685208e-01  1.17941159e-02
#   -5.47113313e-01]]

# %%
plt.barh(features, lr.coef_.flatten())
plt.xlabel('weight')
plt.ylabel('feature')
plt.show()

# %% [markdown]
# сделайте предсказание на тестовых.<br>

# %%
y_pred = lr.predict(X_test)

# %% [markdown]
# Вычислите $R^{2}$ полученных предказаний с помощью r2_score из модуля sklearn.metrics.<br>

# %%
r2_raw = metrics.r2_score(y_test, y_pred)
mse_raw = metrics.mean_squared_error(y_test, y_pred)
abs_raw = metrics.mean_absolute_error(y_test, y_pred)
print(f" R2: {r2_raw}\n mse: {mse_raw}\n abs: {abs_raw}")
# Out:
#  R2: 0.7112260057484943
#  mse: 21.517444231177134
#  abs: 3.1627098714573902

# %% [markdown]
# Ну, и график построим

# %%
plt.scatter(y_pred, y_test)
plt.plot([0, 50], [0, 50], linestyle='--', color='black')
plt.xlabel('predicted values')
plt.ylabel('real values')
# Out:
# Text(0, 0.5, 'real values')

# %% [markdown]
# Тут вот сверху еще график рассеивания значений реальных/предсказанных. и основное задание кончилось,<br> но мне стало интересно, как поменяется качество модели, если данные отмасштабировать (среднее в нуль устремить, а среднеквадратичное отклонение - к единице, как это было сделано в видеоуроке)

# %% [markdown]
# скейлим

# %%
scaler_std = preprocessing.StandardScaler()

# %%
X_train_scaled = scaler_std.fit_transform(X_train)
X_train_scaled = pd.DataFrame(X_train_scaled, columns=features)
X_train_scaled.describe()
# Out:
#                CRIM            ZN         INDUS          CHAS           NOX  \
# count  3.540000e+02  3.540000e+02  3.540000e+02  3.540000e+02  3.540000e+02
# mean  -1.262330e-16 -4.829784e-17  3.724736e-15 -6.680155e-17 -5.443229e-15
# std    1.001415e+00  1.001415e+00  1.001415e+00  1.001415e+00  1.001415e+00
# min   -4.167624e-01 -5.051250e-01 -1.432137e+00 -2.815463e-01 -1.477013e+00
# 25%   -4.079402e-01 -5.051250e-01 -8.663857e-01 -2.815463e-01 -9.196796e-01
# 50%   -3.869638e-01 -5.051250e-01 -2.082672e-01 -2.815463e-01 -1.651363e-01
# 75%   -2.266349e-02  3.807519e-01  1.005500e+00 -2.815463e-01  6.322788e-01
# max    1.029691e+01  3.702790e+00  2.396785e+00  3.551814e+00  2.690124e+00
#
#                  RM           AGE           DIS           RAD           TAX  \
# count  3.540000e+02  3.540000e+02  3.540000e+02  3.540000e+02  3.540000e+02
# mean  -1.594064e-15 -6.962416e-17 -2.244595e-15 -8.185543e-17 -1.890359e-16
# ...

# %% [markdown]
# Когда изучаешь matplotlib, то хочется построить графики всего. Вот графики того, как поменялись std и mean после скелинга, ну, чтоб нагляднее

# %%
scaled_graph = X_train_scaled.describe().T[['std', 'mean']]
X_train_T = X_train.describe().T[['std', 'mean']]

# %%
plt.figure(figsize=(15, 4))

plt.subplot(131)
X_train_T['std'].plot(kind="bar", color='grey', alpha=0.5, logy=True)
scaled_graph['std'].plot(kind='bar', color='red', alpha=0.3, logy=True)
plt.xlabel("std")
plt.ylabel("values")

plt.subplot(132)
scaled_graph['mean'].plot(kind='bar', color='red', alpha=0.7)
plt.xlabel('mean')
plt.ylabel("values")

plt.subplot(133)
X_train_T['mean'].plot(kind="bar", color='grey', alpha=0.3)
plt.xlabel('raw mean')
plt.ylabel("values")

plt.show()

# %%
X_test_scaled = scaler_std.transform(X_test)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=features)

# %%
X_test_scaled.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  152.000000  152.000000  152.000000  152.000000  152.000000  152.000000
# mean     0.057581   -0.005945    0.001791   -0.054571   -0.073193   -0.190217
# std      1.114253    1.106630    0.966544    0.907734    0.976422    0.911601
# min     -0.417092   -0.505125   -1.540380   -0.281546   -1.416992   -3.849476
# 25%     -0.408255   -0.505125   -0.785203   -0.281546   -0.930398   -0.630640
# 50%     -0.388586   -0.505125   -0.208267   -0.281546   -0.216582   -0.231375
# 75%      0.108052   -0.505125    1.005500   -0.281546    0.486515    0.191909
# max      8.437327    3.924259    2.396785    3.551814    2.690124    3.340777
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  152.000000  152.000000  152.000000  152.000000  152.000000  152.000000
# mean    -0.027090    0.045737    0.043042    0.023919    0.262297   -0.116118
# ...

# %% [markdown]
# Теперь посмотрим, как влияет просто масштабирование данных на качество предсказания при линейной регрессии (без отсекания фичей маловесных)

# %%
lr.fit(X_train_scaled, y_train)

plt.barh(features, lr.coef_.flatten())
plt.xlabel('weight')
plt.ylabel('feature')
plt.show()

# %%
y_pred_after_scale = lr.predict(X_test_scaled)

# %%
r2_scaled = metrics.r2_score(y_test, y_pred_after_scale)
mse_scaled = metrics.mean_squared_error(y_test, y_pred_after_scale)
abs_scaled = metrics.mean_absolute_error(y_test, y_pred_after_scale)

print(f" R2: {r2_scaled} was {r2_raw}\n mse: {mse_scaled} was {mse_raw}\n abs: {abs_scaled} was {abs_raw}")
# Out:
#  R2: 0.7112260057484932 was 0.7112260057484943
#  mse: 21.51744423117721 was 21.517444231177134
#  abs: 3.1627098714574053 was 3.1627098714573902

# %% [markdown]
# Очевидно, что никак

# %% [markdown]
# А теперь отсортируем фичи по возрастанию их весов в линейной регрессии

# %%
feature_weight = dict(zip(features, abs(lr.coef_.flatten())))

# %%
feature_weight = dict(sorted(feature_weight.items(), key=lambda item: item[1]))
feature_weight.pop('LSTAT')
feature_weight
# Out:
# {'AGE': 0.2989391755039225,
#  'INDUS': 0.3431346557047966,
#  'ZN': 0.8084399775400768,
#  'CHAS': 0.813864257388578,
#  'B': 1.0237518746405985,
#  'CRIM': 1.1083460154177533,
#  'TAX': 1.4470673128119897,
#  'NOX': 1.7980429490588974,
#  'PTRATIO': 2.052322324086821,
#  'RAD': 2.0941930300437583,
#  'RM': 2.913857995549769,
#  'DIS': 2.942511476980692}

# %% [markdown]
# А теперь будем убирать по одной фиче и смотреть, как будут меняться метрики

# %%
r2_graph = []
mse_graph = []
ame_graph = []
cropped_df_train = X_train_scaled
cropped_df_test = X_test_scaled

for i in feature_weight.keys():
    print(i)
    cropped_df_train = cropped_df_train.drop(columns=i)
    cropped_df_test = cropped_df_test.drop(columns=i)
    #print(cropped_df_train.columns)
    #print(cropped_df_test.columns)
    lr.fit(cropped_df_train, y_train)
    y_pred_cropped = lr.predict(cropped_df_test)
    r2_graph.append(metrics.r2_score(y_test, y_pred_cropped))
    mse_graph.append(metrics.mean_squared_error(y_test, y_pred_cropped))
    ame_graph.append(metrics.mean_absolute_error(y_test, y_pred_cropped))
    print(f'r2: {metrics.r2_score(y_test, y_pred_cropped)}, mse: {metrics.mean_squared_error(y_test, y_pred_cropped)}, ame: {metrics.mean_absolute_error(y_test, y_pred_cropped)}')
# Out:
# AGE
# r2: 0.7138676903216832, mse: 21.32060413611495, ame: 3.1291133750431457
# INDUS
# r2: 0.7149039348907364, mse: 21.2433903455094, ame: 3.113787289886371
# ZN
# r2: 0.7015003386944134, mse: 22.242133789839112, ame: 3.1968689403058326
# CHAS
# r2: 0.7001481595606636, mse: 22.34288884285709, ame: 3.2341202800915103
# B
# r2: 0.7082844781828799, mse: 21.736626555789268, ame: 3.261573132853956
# CRIM
# r2: 0.7108604374224152, mse: 21.544683858794848, ame: 3.216827953507758
# TAX
# r2: 0.6981554117912063, mse: 22.491374647845312, ame: 3.3061402905161827
# NOX
# r2: 0.6613625989838843, mse: 25.232921024767936, ame: 3.469332478227639
# PTRATIO
# r2: 0.6135581438114517, mse: 28.794978961601224, ame: 3.933596807426078
# RAD
# r2: 0.6060897200518729, mse: 29.35147433494005, ame: 4.000208847061039
# RM
# r2: 0.5128403996698898, mse: 36.29976985620141, ame: 4.6666490054067005
# DIS
# r2: 0.4886979007906852, mse: 38.09870218243471, ame: 4.752100511437849

# %%
plt.figure(figsize=(15, 9))

plt.subplot(221)
plt.plot(feature_weight.keys(), r2_graph)
plt.title('r2')

plt.subplot(222)
plt.plot(feature_weight.keys(), mse_graph)
plt.title('mse')

plt.subplot(223)
plt.plot(feature_weight.keys(), ame_graph)
plt.title('ame')
# Out:
# Text(0.5, 1.0, 'ame')

# %% [markdown]
# Видим, что если убрать AGE и INDUS то у $R^{2}$ получается пик, а у остальных - минимумы, что, видимо, является оптимальным вариантом, но также можно видеть, что если убрать фичи вплоть до CRIM, то там тоже своего рода минимум по ошибкам и небольшой максимум в $R^{2}$

# %% [markdown]
# ## Задание 2

# %% [markdown]
# Задание 2
# Создайте модель под названием model с помощью RandomForestRegressor из модуля sklearn.ensemble.
# Сделайте агрумент n_estimators равным 1000,
# max_depth должен быть равен 12 и random_state сделайте равным 42.

# %%
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier

# %%
model = RandomForestRegressor(n_estimators=1000, max_depth=12, random_state=42)

# %% [markdown]
# Обучите модель на тренировочных данных аналогично тому, как вы обучали модель LinearRegression, но при этом в метод fit вместо датафрейма y_train поставьте y_train.values[:, 0], чтобы получить из датафрейма одномерный массив Numpy, так как для класса RandomForestRegressor в данном методе для аргумента y предпочтительно применение массивов вместо датафрейма.

# %%
y_train_forest = y_train.values[:, 0]

# %%
model.fit(X_train_scaled, y_train_forest)
# Out:
# RandomForestRegressor(max_depth=12, n_estimators=1000, random_state=42)

# %% [markdown]
# Сделайте предсказание на тестовых данных и посчитайте R2. Сравните с результатом из предыдущего задания.
# Напишите в комментариях к коду, какая модель в данном случае работает лучше.

# %%
y_pred_forest = model.predict(X_test_scaled)

# %%
metrics.r2_score(y_test, y_pred_forest)
# Out:
# 0.8745853339617797

# %% [markdown]
# У леса коэффициент детерминации лучше, чем у линейной регрессии (у которой 0.714), что говорит о том, что эта модель лучше делает предсказание, чем линейная регрессия.

# %% [markdown]
# Теперь стало интересно, как будет влиять стандартизация данных на лес. Вверху вот лес учился на отскейленных данных, а ниже обучим его на не отскейленных данных

# %%
model.fit(X_train, y_train_forest)
# Out:
# RandomForestRegressor(max_depth=12, n_estimators=1000, random_state=42)

# %%
y_pred_forest = model.predict(X_test)

# %%
metrics.r2_score(y_test, y_pred_forest)
# Out:
# 0.87472606157312

# %% [markdown]
# Было 0,87458 стало 0,87472 - можно даже сказать, что на 0,0001 стало лучше, но думаю, что это несущественно

# %% [markdown]
# ## Задание 3
# Вызовите документацию для класса RandomForestRegressor,<br>
# найдите информацию об атрибуте feature_importances_.<br>
# С помощью этого атрибута найдите сумму всех показателей важности,<br>
# установите, какие два признака показывают наибольшую важность.<br>

# %% [markdown]
# А еще тут в задании указано посчитать сумму признаков, и на вебинаре вы говорили, что надо искать отношение конкретного веса фичи к сумме всех весов (по-моему, мне кажется, что такое было вроде, но щас не могу найти в ноутбуке, который к 7-му вебинару)

# %%
model.feature_importances_.sum()
# Out:
# 1.0

# %% [markdown]
# Но короче суммарный вес единица, поэтому искать $p_{i}/P$, где $p_{i}$ - вес i-го признака, а Р - суммарный вес, можно не искать короче.

# %% [markdown]
# Далее:

# %% [markdown]
# сразу сделаем словарь с фичами и отсортим их по значимости.<br>
# что интересно - веса признаков у линейной регрессии и леса разные

# %%
my_dict = dict(zip(features, model.feature_importances_))
feat_import = dict(sorted(my_dict.items(), key=lambda item: item[1]))
feat_import
# Out:
# {'CHAS': 0.0012362448947738866,
#  'ZN': 0.0015425166262328853,
#  'RAD': 0.00528121831288784,
#  'INDUS': 0.007138131415845556,
#  'TAX': 0.011524934553144586,
#  'B': 0.012450853014007696,
#  'NOX': 0.014268969875348304,
#  'AGE': 0.014298644996729816,
#  'PTRATIO': 0.018081076405025417,
#  'CRIM': 0.03167574073875602,
#  'DIS': 0.06397256527230023,
#  'RM': 0.4026817857034993,
#  'LSTAT': 0.4158473181914483}

# %% [markdown]
# Теперь уберем первые четыре маловесных признака и переобучим модель леса

# %%
test_forest_drop = X_test.drop(columns=['CHAS', 'ZN', 'RAD', 'INDUS'])
train_forest_drop = X_train.drop(columns=['CHAS', 'ZN', 'RAD', 'INDUS'])

# %%
model.fit(train_forest_drop, y_train_forest)
# Out:
# RandomForestRegressor(max_depth=12, n_estimators=1000, random_state=42)

# %%
pred_forest_drop = model.predict(test_forest_drop)

# %%
metrics.r2_score(y_test, pred_forest_drop)
# Out:
# 0.8754246210593307

# %% [markdown]
# Получили метрику, которая слегка выше (было 0,874), чем в случае с полным количеством фичей

# %%
plt.figure(figsize=(15, 6))

plt.subplot(121)
plt.scatter(pred_forest_drop, y_test)
plt.plot([0, 50], [0, 50], linestyle='--', color='black')
plt.title("random forest regressor without few features")
plt.xlabel('predicted values')
plt.ylabel('real values')

plt.subplot(122)
plt.scatter(y_pred, y_test)
plt.plot([0, 50], [0, 50], linestyle='--', color='black')
plt.xlabel('predicted values')
plt.ylabel('real values')
plt.title('linear regression')
# Out:
# Text(0.5, 1.0, 'linear regression')

# %% [markdown]
# Итого: лес с немного выпиленными фичами получше предсказывает, чем совсем сырая линейная регрессия

# %% [markdown]
# ## Задание 4

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">В этом задании мы будем работать с датасетом, с которым мы уже знакомы по домашнему заданию по библиотеке Matplotlib, это датасет Credit Card Fraud Detection.Для этого датасета мы будем решать задачу классификации - будем определять,какие из транзакциции по кредитной карте являются мошенническими. Данный датасет сильно несбалансирован (так как случаи мошенничества относительно редки),так что применение метрики accuracy не принесет пользы и не поможет выбрать лучшую модель.Мы будем вычислять AUC, то есть площадь под кривой ROC.
# Импортируйте из соответствующих модулей RandomForestClassifier, GridSearchCV и train_test_split.

# %% [markdown]
# Загрузите датасет creditcard.csv и создайте датафрейм df.

# %%
df_task4 = pd.read_csv("datasets/creditcard.csv")

# %% [markdown]
# пусть меньше кушает памяти

# %%
df_task4 = reduce_mem_usage(df_task4)
# Out:
# Memory usage of dataframe is 67.36 MB
# Memory usage after optimization is: 32.87 MB
# Decreased by 51.2%

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">Примените следующую настройку, чтобы можно было просматривать все столбцы датафрейма:<br>
# pd.options.display.max_columns = 100.<br>
# Просмотрите первые 10 строк датафрейма df.<br>

# %%
pd.options.display.max_columns=100
df_task4.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9       V10       V11       V12       V13       V14  \
# ...

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">С помощью метода value_counts с аргументом normalize=True убедитесь в том, что выборка несбалансирована.<br>

# %%
pd.DataFrame(df_task4['Class'].value_counts(normalize=True))
# Out:
#       Class
# 0  0.998273
# 1  0.001727

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">Несбалансированной выборкой называется такая выборка, в которой один класс целевой переменной сильно превалирует над другим<br> мошеннеческих операций гораздо меньше, чем нормальных, в общем, вот тут это видно, да

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">Используя метод info, проверьте, все ли столбцы содержат числовые данные и нет ли в них пропусков.</i>

# %%
df_task4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float32
#  1   V1      284807 non-null  float32
#  2   V2      284807 non-null  float32
#  3   V3      284807 non-null  float32
#  4   V4      284807 non-null  float32
#  5   V5      284807 non-null  float32
#  6   V6      284807 non-null  float32
#  7   V7      284807 non-null  float32
#  8   V8      284807 non-null  float32
#  9   V9      284807 non-null  float32
#  10  V10     284807 non-null  float32
#  11  V11     284807 non-null  float32
#  12  V12     284807 non-null  float32
#  13  V13     284807 non-null  float32
#  14  V14     284807 non-null  float32
#  15  V15     284807 non-null  float32
#  16  V16     284807 non-null  float32
#  17  V17     284807 non-null  float32
#  18  V18     284807 non-null  float32
#  19  V19     284807 non-null  float32
# ...

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">Создайте датафрейм X из датафрейма df, исключив столбец Class.

# %%
X_task4 = df_task4.drop(columns='Class')

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">Создайте объект Series под названием y из столбца Class.

# %%
Y_task4 = pd.Series(df_task4['Class'])

# %%
Y_task4.value_counts(normalize=True)
# Out:
# 0    0.998273
# 1    0.001727
# Name: Class, dtype: float64

# %% [markdown]
# Разбейте X и y на тренировочный и тестовый наборы данных при помощи функции train_test_split, используя аргументы: test_size=0.3, random_state=100, stratify=y.

# %%
X_train_task4, X_test_task4, y_train_task4, y_test_task4 = train_test_split(X_task4, Y_task4, test_size=0.3, random_state=100, stratify=Y_task4)

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">У вас должны получиться объекты X_train, X_test, y_train и y_test.
# Просмотрите информацию о их форме.

# %%
print(f"Shapes are\nX_train: {X_train_task4.shape}, X_test: {X_test_task4.shape}\ny_train: {y_train_task4.shape}, y_test: {y_test_task4.shape}")
# Out:
# Shapes are
# X_train: (199364, 30), X_test: (85443, 30)
# y_train: (199364,), y_test: (85443,)

# %% [markdown]
# Для поиска по сетке параметров задайте такие параметры:
# parameters = [{'n_estimators': [10, 15],
# 'max_features': np.arange(3, 5),
# 'max_depth': np.arange(4, 7)}]

# %%
parameters_for_grid = [{'n_estimators': [10, 15],
'max_features': np.arange(3, 5),
'max_depth': np.arange(4, 7)}]

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">Создайте модель GridSearchCV со следующими аргументами:<br>
# estimator=RandomForestClassifier(random_state=100),<br>
# param_grid=parameters,<br>
# scoring='roc_auc',<br>
# cv=3.<br>
#     </p>

# %%
clf = GridSearchCV(
    estimator=RandomForestClassifier(random_state=100),
    param_grid=parameters_for_grid,
    scoring='roc_auc',
    cv=3
)

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">Обучите модель на тренировочном наборе данных (может занять несколько минут).

# %%
# %%time
clf.fit(X_train_task4, y_train_task4)
# Out:
# Wall time: 1min 42s
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=100),
#              param_grid=[{'max_depth': array([4, 5, 6]),
#                           'max_features': array([3, 4]),
#                           'n_estimators': [10, 15]}],
#              scoring='roc_auc')

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">Просмотрите параметры лучшей модели с помощью атрибута best_params_.

# %%
clf.best_params_
# Out:
# {'max_depth': 6, 'max_features': 3, 'n_estimators': 15}

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">Предскажите вероятности классов с помощью полученнной модели и метода predict_proba.

# %%
y_pred_task4 = clf.predict(X_test_task4)

# %%
y_pred_task4_proba = clf.predict_proba(X_test_task4)

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">Из полученного результата (массив Numpy) выберите столбец с индексом 1 (вероятность класса 1) и запишите в массив y_pred_proba

# %%
y_pred_task4_proba = y_pred_task4_proba[:, 1]
print(y_pred_task4_proba)
# Out:
# [0.00092917 0.00029521 0.00028215 ... 0.00028215 0.0006822  0.01246098]

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">Из модуля sklearn.metrics импортируйте метрику roc_auc_score. (там все импорты выше)<br>
# Вычислите AUC на тестовых данных и сравните с результатом,полученным на тренировочных данных, используя в качестве аргументовмассивы y_test и y_pred_proba.

# %%
metrics.roc_auc_score(y_test_task4, y_pred_task4_proba)
# Out:
# 0.9462664156037156

# %%
metrics.roc_auc_score(y_train_task4 ,clf.predict_proba(X_train_task4)[:, 1])
# Out:
# 0.9703527882554751

# %%
fpr, tpr, _ = metrics.roc_curve(y_test_task4, y_pred_task4_proba, pos_label=1)

# %%
fpr_train, tpr_train, _ = metrics.roc_curve(y_train_task4, clf.predict_proba(X_train_task4)[:, 1], pos_label=1)

# %%
plt.figure(figsize=(14, 4))

plt.subplot(121)
plt.plot(fpr_train, tpr_train)
plt.plot([0, 1], [0, 1], color='grey', linestyle='dashed')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve train, auc = 0.970')

plt.subplot(122)
plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], color='grey', linestyle='dashed')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve test, auc = 0.946')

plt.show()

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">Решил еще построить сами ROC кривые, где видно наглядно, что у правой (где тестовые данные) угол немного скошен (и площадь, соответсвенно, меньше)

# %% [markdown]
# ## Задание 5

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">
# 1). Загрузите датасет Wine из встроенных датасетов sklearn.datasets с помощью функции load_wine в переменную data.

# %%
wine = datasets.load_wine()

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">2). Полученный датасет не является датафреймом. Это структура данных, имеющая ключи аналогично словарю. Просмотрите тип данных этой структуры данных и создайте список data_keys, содержащий ее ключи.

# %%
data_keys = wine.keys()
data_keys
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names'])

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">3). Просмотрите данные, описание и названия признаков в датасете. Описание нужно вывести в виде привычного, аккуратно оформленного текста, без обозначений переноса строки, но с самими переносами и т.д.

# %%
print(wine['DESCR'])
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 178 (50 in each of three classes)
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- Alcohol
#  		- Malic acid
#  		- Ash
# 		- Alcalinity of ash
#  		- Magnesium
# 		- Total phenols
#  		- Flavanoids
#  		- Nonflavanoid phenols
#  		- Proanthocyanins
# 		- Color intensity
#  		- Hue
#  		- OD280/OD315 of diluted wines
#  		- Proline
#
#     - class:
#             - class_0
#             - class_1
#             - class_2
#
#     :Summary Statistics:
#
#     ============================= ==== ===== ======= =====
#                                    Min   Max   Mean     SD
#     ============================= ==== ===== ======= =====
#     Alcohol:                      11.0  14.8    13.0   0.8
#     Malic Acid:                   0.74  5.80    2.34  1.12
# ...

# %%
print(wine['feature_names'])
# Out:
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">4). Сколько классов содержит целевая переменная датасета? Выведите названия классов.

# %%
print(wine['target_names'])
# Out:
# ['class_0' 'class_1' 'class_2']

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">5). На основе данных датасета (они содержатся в двумерном массиве Numpy) и названий признаков создайте датафрейм под названием X.

# %%
X_task5 = pd.DataFrame(wine['data'], columns=wine['feature_names'])

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">6). Выясните размер датафрейма X и установитпе, имеются ли в нем пропущенные значения.

# %%
X_task5.shape
# Out:
# (178, 13)

# %%
X_task5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">Нулевых значений нет

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">7). Добавьте в датафрейм поле с классами вин в виде чисел, имеющих тип данных numpy.int64. Название поля - 'target'.

# %%
X_task5['target'] = wine['target']

# %%
X_task5.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
X_task5['target'] = X_task5['target'].astype(np.int64)

# %%
X_task5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %%
X_task5 = reduce_mem_usage(X_task5)
# Out:
# Memory usage of dataframe is 0.02 MB
# Memory usage after optimization is: 0.01 MB
# Decreased by 52.3%

# %%
X_task5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float32
#  1   malic_acid                    178 non-null    float32
#  2   ash                           178 non-null    float32
#  3   alcalinity_of_ash             178 non-null    float32
#  4   magnesium                     178 non-null    float32
#  5   total_phenols                 178 non-null    float32
#  6   flavanoids                    178 non-null    float32
#  7   nonflavanoid_phenols          178 non-null    float32
#  8   proanthocyanins               178 non-null    float32
#  9   color_intensity               178 non-null    float32
#  10  hue                           178 non-null    float32
#  11  od280/od315_of_diluted_wines  178 non-null    float32
# ...

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">Это вот щас было не по заданию, но тут инт64 под значения, которые только бывают 0, 1 и 2 - жирно это как-то, мне кажется

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">8). Постройте матрицу корреляций для всех полей X. Дайте полученному датафрейму название X_corr.

# %%
X_task5_corr = X_task5.corr()

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">на семинаре по графикам была красивишная матрица корреляций. тоже вот сделал

# %%
plt.figure(figsize = (10,8))

sns.heatmap(X_task5_corr, annot=True, cmap='crest')

plt.title('Correlation matrix')
plt.show()

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">9). Создайте список high_corr из признаков, корреляция которых с полем target по абсолютному значению превышает 0.5 (причем, само поле target не должно входить в этот список).

# %%
high_corr = X_task5_corr.query(' abs(target) > 0.5')['target'].drop(index='target').index
high_corr = list(high_corr)
high_corr
# Out:
# ['alcalinity_of_ash',
#  'total_phenols',
#  'flavanoids',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %% [markdown]
# <p style="font-size:11.5pt; line-height: 1.8">10). Удалите из датафрейма X поле с целевой переменной.<br> Для всех признаков, названия которых содержатся в списке high_corr, вычислите квадрат их значений и добавьте в датафрейм X соответствующие поля с суффиксом '_2', добавленного к первоначальному названию признака.<br> Итоговый датафрейм должен содержать все поля, которые, были в нем изначально, а также поля с признаками из списка high_corr, возведенными в квадрат. Выведите описание полей датафрейма X с помощью метода describe.

# %%
X_task5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float32
#  1   malic_acid                    178 non-null    float32
#  2   ash                           178 non-null    float32
#  3   alcalinity_of_ash             178 non-null    float32
#  4   magnesium                     178 non-null    float32
#  5   total_phenols                 178 non-null    float32
#  6   flavanoids                    178 non-null    float32
#  7   nonflavanoid_phenols          178 non-null    float32
#  8   proanthocyanins               178 non-null    float32
#  9   color_intensity               178 non-null    float32
#  10  hue                           178 non-null    float32
#  11  od280/od315_of_diluted_wines  178 non-null    float32
# ...

# %%
X_task5.drop(columns='target', inplace=True)

# %%
X_task5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float32
#  1   malic_acid                    178 non-null    float32
#  2   ash                           178 non-null    float32
#  3   alcalinity_of_ash             178 non-null    float32
#  4   magnesium                     178 non-null    float32
#  5   total_phenols                 178 non-null    float32
#  6   flavanoids                    178 non-null    float32
#  7   nonflavanoid_phenols          178 non-null    float32
#  8   proanthocyanins               178 non-null    float32
#  9   color_intensity               178 non-null    float32
#  10  hue                           178 non-null    float32
#  11  od280/od315_of_diluted_wines  178 non-null    float32
# ...

# %% [markdown]
# Таргет ушел

# %%
for i in high_corr:
    X_task5[f'{i}_2'] = X_task5[i] ** 2

# %%
X_task5.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43          15.600000      127.0           2.80
# 1    13.20        1.78  2.14          11.200000      100.0           2.65
# 2    13.16        2.36  2.67          18.600000      101.0           2.80
# 3    14.37        1.95  2.50          16.799999      113.0           3.85
# 4    13.24        2.59  2.87          21.000000      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
# ...

# %%
X_task5.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000614    2.336348    2.366518          19.494946   99.741570
# std      0.811827    1.117146    0.274344           3.339564   14.282485
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200001   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %% [markdown]
# Фсе
